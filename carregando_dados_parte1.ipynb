# %% [markdown]
# #### Análise de Dados com PYTHON.
# - Visualização dos Dados.

# %% [markdown]
# #### * Carregando dados com PANDAS

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas

# %% [markdown]
# ###### A fim de evitar ficar chamando a todo momento uma biblioteca podemos atribuir a elas, apelidos, para mais rapidez e facilidade nos códigos
# ###### Porém estes apelidos seguem padrões dentro da comunidade PY, exemplo disso é a pandas que tem como apelido o pd

# %%
import pandas as pd

# %%
# importando dados de um arquivo csv - lembrando que o arquivo deve estar dentro da nossa pasta de desenvolvimento

dados = pd.read_csv("base_dados.csv")                    # read = ler

# %%
# verificando as primeiras linhas carregadas

dados.head()                                             # head = cabeçalho
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido  dt_entrega motivo_devolucao    status
# 0             SP         139.5  2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4  2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5  2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0  2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6  2019-03-07       S/ Devolu.  Atrasado

# %%
dados.head(10)                        # verificando as 10 primeiras linhas
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
# 5           A16         WALMART       JOÃO GOMES        2019-02-23
# 6           A17         WALMART       JOÃO GOMES        2019-02-24
# 7           A20  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-26
# 8           A22      AMERICANAS  VALDIR ESPINOSA        2019-03-01
# 9           A23      AMERICANAS     MARCOS LEROY        2019-03-02
#
#   estado_destino  valor_pedido  dt_entrega motivo_devolucao    status
# 0             SP         139.5  2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4  2019-02-12       S/ Devolu.  Atrasado
# ...

# %%
# verificar as últimas linhas carregadas

dados.tail()                                     # tail = rabo (últimas)
# Out:
#      numero_pedido         cliente        motorista dt_emissao_pedido  \
# 4277         A9675  MAGAZINE LUIZA  VALDIR ESPINOSA        2021-11-27
# 4278         A9676         WALMART      LUIZ PARDAL        2021-11-28
# 4279         A9680    CASA E VIDEO   TÚLIO SILVEIRA        2021-12-02
# 4280         A9681  RICARDO ELETRO     MARCOS LEROY        2021-12-03
# 4281         A9683      AMERICANAS     FELIPE SILVA        2021-12-06
#
#      estado_destino  valor_pedido  dt_entrega motivo_devolucao    status
# 4277             RJ         763.2  2021-12-15   Produto Errado  Atrasado
# 4278             SP         226.8  2021-12-12   Produto Errado  Atrasado
# 4279             SP         821.1  2021-12-20       Danificado  Atrasado
# 4280             SP          49.8  2021-12-17       S/ Devolu.  Atrasado
# 4281             BH         715.5  2021-12-17       Danificado  Atrasado

# %%
# verificando o tamanho da base de dados, que será apresentado pelo comando shape, a quantidade de linhas e de colunas

dados.shape                           # por ser uma propriedade e não um método o shape não exige os parênteses
# Out:
# (4282, 9)

# %% [markdown]
# #### Carregando dados com Excel

# %% [markdown]
# ###### - Recomenda-se, por uma boa prática, que se faça uma análise exploratória dos dados recebidos antes de joga-lo em nosso sistema.
# ###### - Mas do que se trata essa análise exploratória?
# ######   * Abrir o arquivo recebido, saber sobre suas abas e se não há abas ocultas, se houver deve-se abri-las;
# ######   * Estudar e entender os dados e as colunas do arquivo recebido;
# ######   * Saber o número de linhas existentes nesses arquivos, no caso do excell para chegar nessa informação -> na linha A2 CTRL + SHIFT + seta p/ baixo

# %%
dados = pd.read_excel("base_dados.xlsx")

# %%
# Verificando as primeiras linhas

dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %%
# Verificando as últimas linhas

dados.tail()
# Out:
#      numero_pedido         cliente        motorista dt_emissao_pedido  \
# 4277         A9675  MAGAZINE LUIZA  VALDIR ESPINOSA        2021-11-27
# 4278         A9676         WALMART      LUIZ PARDAL        2021-11-28
# 4279         A9680    CASA E VIDEO   TÚLIO SILVEIRA        2021-12-02
# 4280         A9681  RICARDO ELETRO     MARCOS LEROY        2021-12-03
# 4281         A9683      AMERICANAS     FELIPE SILVA        2021-12-06
#
#      estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 4277             RJ         763.2 2021-12-15   Produto Errado  Atrasado
# 4278             SP         226.8 2021-12-12   Produto Errado  Atrasado
# 4279             SP         821.1 2021-12-20       Danificado  Atrasado
# 4280             SP          49.8 2021-12-17       S/ Devolu.  Atrasado
# 4281             BH         715.5 2021-12-17       Danificado  Atrasado

# %%
# Verificando o tamanho da base de dados

dados.shape                  # Lembrando que,shape, por ser uma propriedade e não um método não exige os parêntese no final
# Out:
# (4282, 9)

# %% [markdown]
# #### Verificando o tipo de dados das colunas

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4282 entries, 0 to 4281
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   numero_pedido      4282 non-null   object
#  1   cliente            4282 non-null   object
#  2   motorista          4282 non-null   object
#  3   dt_emissao_pedido  4282 non-null   datetime64[ns]
#  4   estado_destino     4282 non-null   object
#  5   valor_pedido       4282 non-null   float64
#  6   dt_entrega         4282 non-null   datetime64[ns]
#  7   motivo_devolucao   4282 non-null   object
#  8   status             4282 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(6)
# memory usage: 301.2+ KB

# %% [markdown]
#      - As informações acima nos trás:
# - 4282 linhas no arquivo;
# - em 9 colunas;
# - o nome das colunas;
# - non-null, que indica que não há nenhuma linha sem dado; (no-null deve ser aprofundado, pois trat-se de uma análise mais apurada)
# - e o dtype, que trás a informação de 'object', que indica que é uma strings
# - datetime que é uma coluna de data e hora;
# - há na tabela valores float, informações não inteiras (float64)

# %%
# Podemos verificar o tipo de dado da variável dados

type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Acessando Colunas individualmente
# - Dados tabular -> trata-se de uma tabela com uma sequência de linhas e colunas.

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %%
# Acessando a coluna cliente

dados["cliente"]
# Out:
# 0              WALMART
# 1       MAGAZINE LUIZA
# 2       MAGAZINE LUIZA
# 3       MAGAZINE LUIZA
# 4              WALMART
#              ...
# 4277    MAGAZINE LUIZA
# 4278           WALMART
# 4279      CASA E VIDEO
# 4280    RICARDO ELETRO
# 4281        AMERICANAS
# Name: cliente, Length: 4282, dtype: object

# %%
# Acessando a coluna número pedido

dados["numero_pedido"]
# Out:
# 0          A3
# 1          A4
# 2          A7
# 3         A12
# 4         A15
#         ...
# 4277    A9675
# 4278    A9676
# 4279    A9680
# 4280    A9681
# 4281    A9683
# Name: numero_pedido, Length: 4282, dtype: object

# %%
# Acessando multiplas colunas

dados[["cliente", "estado_destino"]]
# Out:
#              cliente estado_destino
# 0            WALMART             SP
# 1     MAGAZINE LUIZA             RJ
# 2     MAGAZINE LUIZA             SP
# 3     MAGAZINE LUIZA             SP
# 4            WALMART             RJ
# ...              ...            ...
# 4277  MAGAZINE LUIZA             RJ
# 4278         WALMART             SP
# 4279    CASA E VIDEO             SP
# 4280  RICARDO ELETRO             SP
# 4281      AMERICANAS             BH
#
# [4282 rows x 2 columns]

# %%
# Dentro da análise podemos criar uma lista recebendo o nome de uma varíavel e solicita-la no Data Frame.

colunas = ["cliente", "motorista", "estado_destino","status"]

dados[colunas]
# Out:
#              cliente        motorista estado_destino    status
# 0            WALMART     FELIPE SILVA             SP  No Prazo
# 1     MAGAZINE LUIZA   TÚLIO SILVEIRA             RJ  Atrasado
# 2     MAGAZINE LUIZA  VALDIR ESPINOSA             SP  No Prazo
# 3     MAGAZINE LUIZA     MARCOS LEROY             SP  No Prazo
# 4            WALMART      LUIZ PARDAL             RJ  Atrasado
# ...              ...              ...            ...       ...
# 4277  MAGAZINE LUIZA  VALDIR ESPINOSA             RJ  Atrasado
# 4278         WALMART      LUIZ PARDAL             SP  Atrasado
# 4279    CASA E VIDEO   TÚLIO SILVEIRA             SP  Atrasado
# 4280  RICARDO ELETRO     MARCOS LEROY             SP  Atrasado
# 4281      AMERICANAS     FELIPE SILVA             BH  Atrasado
#
# [4282 rows x 4 columns]

# %% [markdown]
# #### Acessando as Linhas

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %% [markdown]
# ###### Os números sequênciais nas linhas, são índices criados automaticamente pelo carregamento do sistema e são idependentes das sequências da página do excel.
# ###### PANDAS trata-se de uma biblioteca muito poderosa e entre esses poderes há várias formas de se chamar dados. Porém como estamos no aprendizado de melhores práticas, vamos fazer a seleção de linhas pelo método loc (localization).

# %%
dados.loc[0]
# Out:
# numero_pedido                         A3
# cliente                          WALMART
# motorista                   FELIPE SILVA
# dt_emissao_pedido    2019-01-27 00:00:00
# estado_destino                        SP
# valor_pedido                       139.5
# dt_entrega           2019-02-03 00:00:00
# motivo_devolucao              S/ Devolu.
# status                          No Prazo
# Name: 0, dtype: object

# %%
dados.loc[77]
# Out:
# numero_pedido                       A185
# cliente                       AMERICANAS
# motorista                    LUIZ PARDAL
# dt_emissao_pedido    2019-07-05 00:00:00
# estado_destino                        BH
# valor_pedido                       806.4
# dt_entrega           2019-07-18 00:00:00
# motivo_devolucao          Produto Errado
# status                          Atrasado
# Name: 77, dtype: object

# %%
# Selecionar linhas e colunas com loc

dados.loc[0, "cliente"]
# Out:
# 'WALMART'

# %%
dados.loc[0, "motorista"]
# Out:
# 'FELIPE SILVA'

# %%
dados.loc[0, ["cliente", "motorista"]]
# Out:
# cliente           WALMART
# motorista    FELIPE SILVA
# Name: 0, dtype: object

# %% [markdown]
# #### Filtrando Linhas e Colunas
# - Utilizando dado Booleano (bool que tem seu status como True or False)

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %%
# Vamos fazer dentro do Data Frame um filtro buscando apenas os dados do WALMART

dados["cliente"] == "WALMART"
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4277    False
# 4278     True
# 4279    False
# 4280    False
# 4281    False
# Name: cliente, Length: 4282, dtype: bool

# %%
# Com as informações recebidas acima podemos criar nosso filtro com uma varíavel, a qual pode receber qualquer nome, no caso filtro

filtro = dados["cliente"] == "WALMART"

dados[filtro]
# Out:
#      numero_pedido  cliente     motorista dt_emissao_pedido estado_destino  \
# 0               A3  WALMART  FELIPE SILVA        2019-01-27             SP
# 4              A15  WALMART   LUIZ PARDAL        2019-02-21             RJ
# 5              A16  WALMART    JOÃO GOMES        2019-02-23             RJ
# 6              A17  WALMART    JOÃO GOMES        2019-02-24             SP
# 11             A27  WALMART  FELIPE SILVA        2019-03-07             BH
# ...            ...      ...           ...               ...            ...
# 4257         A9640  WALMART    JOÃO GOMES        2021-11-03             BH
# 4268         A9656  WALMART    JOÃO GOMES        2021-11-09             BH
# 4270         A9659  WALMART   LUIZ PARDAL        2021-11-10             RJ
# 4275         A9672  WALMART    JOÃO GOMES        2021-11-24             SP
# 4278         A9676  WALMART   LUIZ PARDAL        2021-11-28             SP
#
#       valor_pedido dt_entrega motivo_devolucao    status
# ...

# %%
# Pórem podemos ter o mesmo resultado usando o loc

dados.loc[filtro, ["cliente", "motorista"]]
# Out:
#       cliente     motorista
# 0     WALMART  FELIPE SILVA
# 4     WALMART   LUIZ PARDAL
# 5     WALMART    JOÃO GOMES
# 6     WALMART    JOÃO GOMES
# 11    WALMART  FELIPE SILVA
# ...       ...           ...
# 4257  WALMART    JOÃO GOMES
# 4268  WALMART    JOÃO GOMES
# 4270  WALMART   LUIZ PARDAL
# 4275  WALMART    JOÃO GOMES
# 4278  WALMART   LUIZ PARDAL
#
# [1157 rows x 2 columns]

# %%
# Se precisar de toda coluna

dados.loc[filtro]
# Out:
#      numero_pedido  cliente     motorista dt_emissao_pedido estado_destino  \
# 0               A3  WALMART  FELIPE SILVA        2019-01-27             SP
# 4              A15  WALMART   LUIZ PARDAL        2019-02-21             RJ
# 5              A16  WALMART    JOÃO GOMES        2019-02-23             RJ
# 6              A17  WALMART    JOÃO GOMES        2019-02-24             SP
# 11             A27  WALMART  FELIPE SILVA        2019-03-07             BH
# ...            ...      ...           ...               ...            ...
# 4257         A9640  WALMART    JOÃO GOMES        2021-11-03             BH
# 4268         A9656  WALMART    JOÃO GOMES        2021-11-09             BH
# 4270         A9659  WALMART   LUIZ PARDAL        2021-11-10             RJ
# 4275         A9672  WALMART    JOÃO GOMES        2021-11-24             SP
# 4278         A9676  WALMART   LUIZ PARDAL        2021-11-28             SP
#
#       valor_pedido dt_entrega motivo_devolucao    status
# ...

# %% [markdown]
# ###### Lembrando que veio toda Data Frame do filtro WALMART, como foi especificado na váriavel -> filtro = dados["cliente"] == "WALMART"

# %%
# Podemos fazer ainda a GRAVAÇÃO dessas informações dentro de um váriavel

dados_walmart = dados.loc[filtro]

dados_walmart
# Out:
#      numero_pedido  cliente     motorista dt_emissao_pedido estado_destino  \
# 0               A3  WALMART  FELIPE SILVA        2019-01-27             SP
# 4              A15  WALMART   LUIZ PARDAL        2019-02-21             RJ
# 5              A16  WALMART    JOÃO GOMES        2019-02-23             RJ
# 6              A17  WALMART    JOÃO GOMES        2019-02-24             SP
# 11             A27  WALMART  FELIPE SILVA        2019-03-07             BH
# ...            ...      ...           ...               ...            ...
# 4257         A9640  WALMART    JOÃO GOMES        2021-11-03             BH
# 4268         A9656  WALMART    JOÃO GOMES        2021-11-09             BH
# 4270         A9659  WALMART   LUIZ PARDAL        2021-11-10             RJ
# 4275         A9672  WALMART    JOÃO GOMES        2021-11-24             SP
# 4278         A9676  WALMART   LUIZ PARDAL        2021-11-28             SP
#
#       valor_pedido dt_entrega motivo_devolucao    status
# ...

# %%
# Filtrando todas as linhas onde a coluna estado_destino for igual a BH

filtro_bh = dados["estado_destino"] == "BH"
dados.loc[filtro_bh]
# Out:
#      numero_pedido         cliente        motorista dt_emissao_pedido  \
# 7              A20  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-26
# 11             A27         WALMART     FELIPE SILVA        2019-03-07
# 14             A35         WALMART     FELIPE SILVA        2019-03-17
# 15             A36         WALMART     MARCOS LEROY        2019-03-18
# 17             A38         WALMART      LUIZ PARDAL        2019-03-22
# ...            ...             ...              ...               ...
# 4268         A9656         WALMART       JOÃO GOMES        2021-11-09
# 4271         A9662     CASAS BAHIA     FELIPE SILVA        2021-11-12
# 4274         A9668    CASA E VIDEO   TÚLIO SILVEIRA        2021-11-15
# 4276         A9673     CASAS BAHIA     FELIPE SILVA        2021-11-25
# 4281         A9683      AMERICANAS     FELIPE SILVA        2021-12-06
#
#      estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# ...

# %% [markdown]
# #### Exportando um DataFrame

# %%
dados.loc[filtro_bh]                    # Abaixo temos toda base de dados relacionados com o Estado de Belo Horizonte
# Out:
#      numero_pedido         cliente        motorista dt_emissao_pedido  \
# 7              A20  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-26
# 11             A27         WALMART     FELIPE SILVA        2019-03-07
# 14             A35         WALMART     FELIPE SILVA        2019-03-17
# 15             A36         WALMART     MARCOS LEROY        2019-03-18
# 17             A38         WALMART      LUIZ PARDAL        2019-03-22
# ...            ...             ...              ...               ...
# 4268         A9656         WALMART       JOÃO GOMES        2021-11-09
# 4271         A9662     CASAS BAHIA     FELIPE SILVA        2021-11-12
# 4274         A9668    CASA E VIDEO   TÚLIO SILVEIRA        2021-11-15
# 4276         A9673     CASAS BAHIA     FELIPE SILVA        2021-11-25
# 4281         A9683      AMERICANAS     FELIPE SILVA        2021-12-06
#
#      estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# ...

# %%
# Entendendo que a análise dos dados está satisfatória e precisamos salvá-la em um arquivo.
# Exportando para o EXCEL

dados.loc[filtro_bh].to_excel("dados_BH.xlsx", index=False)           # dados.loc[filtro_bh] -> solicitado ao PANDAS que pegue esse arquivo
                                                                      # .to_excel            -> exporta essas informações para o EXCEL
                                                                      # "dados_BH.xlsx"      -> com esse nome de arquivo
                                                                      # index=False          -> solicitado ao PANDAS para NÂO exportar o índice(index)

# %% [markdown]
# ###### se observado nos nossos arquivos no canto superior esquerdo, do VSCode, está criado o arquivo dados_BH.xlsx, bem como na pasta arquivos pessoais do PC.

# %%
# Agora vamos Exportar os dados do WALMART, para um arquivo CSV

dados_walmart.to_csv("dados_walmart.csv", index=False)

# %% [markdown]
# #### Cálculos com a Base de Dados

# %% [markdown]
# #### Gerando estatísticas
# - Será gerado estatísticas na coluna valor_pedido

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %%
dados['valor_pedido'].describe()
# Out:
# count    4282.000000
# mean      339.038230
# std       244.817324
# min        15.000000
# 25%       144.900000
# 50%       279.000000
# 75%       505.600000
# max      1020.000000
# Name: valor_pedido, dtype: float64

# %% [markdown]
# ###### count -> trás os valores de contagem que há na coluna solicitada
# ###### mean  -> é a média de preço de todos os pedidos
# ###### std   -> desvio padrão que indica o grau de variação de um conjunto de elementos. (ex.:a média de variação de 3 cálculos)
# ###### min   -> é o valor de pedido mais barato
# ###### 25%   -> as porcentagens são conhecidas como QUARTIS e a de 25% é o primeiro quartil, que indica que 25% dos pedidos é até o valor expressado
# ###### 50%   -> segundo quartil ou mediana e indica que 50% dos pedidos é de até o valor expressado
# ###### 75%   -> terceiro quartil e indica que 75% dos pedidos é de até o valor expressado
# ###### max   -> trás o pedido de maior valor

# %% [markdown]
# #### Cálculos com PANDAS parte 2
# #### Contagem de Valores Únicos
# ###### Trata-se de um processo importante pois trás muitas informações importantes dentro de uma análise

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %% [markdown]
# ##### * Visualizando valores distintos

# %%
# Visualizando os valores únicos de uma coluna

dados["cliente"].unique()
# Out:
# array(['WALMART', 'MAGAZINE LUIZA', 'AMERICANAS', 'CASAS BAHIA',
#        'CASA E VIDEO', 'RICARDO ELETRO'], dtype=object)

# %%
# Visualizando os motoristas da empresa

dados["motorista"].unique()
# Out:
# array(['FELIPE SILVA', 'TÚLIO SILVEIRA', 'VALDIR ESPINOSA',
#        'MARCOS LEROY', 'LUIZ PARDAL', 'JOÃO GOMES'], dtype=object)

# %%
# Visualizar os estados de destino

dados["estado_destino"].unique()
# Out:
# array(['SP', 'RJ', 'BH'], dtype=object)

# %% [markdown]
# #### * Contagem de valores distintos

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %%
# Contando valores distintos para clientes, onde cada loja irá mostrar o número de pedidos

dados["cliente"].value_counts()
# Out:
# cliente
# WALMART           1157
# CASAS BAHIA       1016
# MAGAZINE LUIZA     809
# AMERICANAS         591
# CASA E VIDEO       385
# RICARDO ELETRO     324
# Name: count, dtype: int64

# %%
# Motorista com o maior número de pedidos

dados["motorista"].value_counts()
# Out:
# motorista
# MARCOS LEROY       753
# LUIZ PARDAL        750
# VALDIR ESPINOSA    732
# TÚLIO SILVEIRA     698
# JOÃO GOMES         685
# FELIPE SILVA       664
# Name: count, dtype: int64

# %%
# Quantidade de pedidos por estado destino

dados["estado_destino"].value_counts()
# Out:
# estado_destino
# BH    1496
# SP    1412
# RJ    1374
# Name: count, dtype: int64

# %% [markdown]
# #### Aplicando estatísticas

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %% [markdown]
# #### * Média (mean)

# %%
dados["valor_pedido"].mean()

# Os resultados de média fazem sentido para colunas numéricas
# Out:
# np.float64(339.0382297991593)

# %% [markdown]
# ##### *Mediana (median)

# %%
dados["valor_pedido"].median()
# Out:
# np.float64(279.0)

# %% [markdown]
# ##### *Desvio Padrão

# %%
dados["valor_pedido"].std()
# Out:
# np.float64(244.81732413883788)

# %% [markdown]
# ##### *Valor máximo

# %%
dados["valor_pedido"].max()
# Out:
# np.float64(1020.0000000000007)

# %%
# Qual é a data do último pedido?

dados["dt_emissao_pedido"].max()
# Out:
# Timestamp('2021-12-06 00:00:00')

# %%
# Qual é a última data de entrega

dados["dt_entrega"].max()
# Out:
# Timestamp('2021-12-20 00:00:00')

# %% [markdown]
# ##### *Valor minímo

# %%
dados["valor_pedido"].min()
# Out:
# np.float64(15.0)

# %%
# Qual é a menor data de pedido?

dados["dt_emissao_pedido"].min()
# Out:
# Timestamp('2019-01-27 00:00:00')

# %%
# Qual a entrega mais antiga da base de dados?

dados["dt_emissao_pedido"].min()
# Out:
# Timestamp('2019-01-27 00:00:00')

# %% [markdown]
# #### Agrupando Valores

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %% [markdown]
# ###### Para cada um dos clientes podemos somar os valores dos pedidos, valores de produtos por motoristas,etc

# %%
# Mostrando o valor total de pedidos de cada cliente

dados.groupby("cliente")["valor_pedido"].sum()
# Out:
# cliente
# AMERICANAS        188903.6
# CASA E VIDEO      131108.2
# CASAS BAHIA       348189.8
# MAGAZINE LUIZA    285890.9
# RICARDO ELETRO    104503.3
# WALMART           393165.9
# Name: valor_pedido, dtype: float64

# %%
# Mostrando o valor total de pedidos por motorista

dados.groupby("motorista")["valor_pedido"].sum()
# Out:
# motorista
# FELIPE SILVA       224024.7
# JOÃO GOMES         237449.6
# LUIZ PARDAL        251138.9
# MARCOS LEROY       262353.2
# TÚLIO SILVEIRA     243329.3
# VALDIR ESPINOSA    233466.0
# Name: valor_pedido, dtype: float64

# %%
# Qual o valor médio de pedido por Estado destino?

dados.groupby("estado_destino")["valor_pedido"].mean()
# Out:
# estado_destino
# BH    335.017781
# RJ    348.699418
# SP    333.896671
# Name: valor_pedido, dtype: float64

# %% [markdown]
# ##### * Agrupando por múltiplas colunas

# %%
# Agrupando por cliente e estado destino

dados.groupby(["cliente", "estado_destino",])["valor_pedido"].sum()
# Out:
# cliente         estado_destino
# AMERICANAS      BH                 64648.1
#                 RJ                 66547.8
#                 SP                 57707.7
# CASA E VIDEO    BH                 41805.8
#                 RJ                 47779.2
#                 SP                 41523.2
# CASAS BAHIA     BH                128301.9
#                 RJ                110400.7
#                 SP                109487.2
# MAGAZINE LUIZA  BH                 95455.2
#                 RJ                 94038.0
#                 SP                 96397.7
# RICARDO ELETRO  BH                 30196.0
#                 RJ                 35755.3
#                 SP                 38552.0
# WALMART         BH                140779.6
#                 RJ                124592.0
#                 SP                127794.3
# Name: valor_pedido, dtype: float64

# %%
# Melhorando a apresentação dos dados acima com o comando to_frame()

dados.groupby(["cliente", "estado_destino",])["valor_pedido"].sum().to_frame()
# Out:
#                                valor_pedido
# cliente        estado_destino
# AMERICANAS     BH                   64648.1
#                RJ                   66547.8
#                SP                   57707.7
# CASA E VIDEO   BH                   41805.8
#                RJ                   47779.2
#                SP                   41523.2
# CASAS BAHIA    BH                  128301.9
#                RJ                  110400.7
#                SP                  109487.2
# MAGAZINE LUIZA BH                   95455.2
#                RJ                   94038.0
#                SP                   96397.7
# RICARDO ELETRO BH                   30196.0
#                RJ                   35755.3
#                SP                   38552.0
# WALMART        BH                  140779.6
#                RJ                  124592.0
#                SP                  127794.3

# %%
# Qual é o total de pedidos por cliente e por estado destino

dados.groupby(["cliente", "estado_destino",])["numero_pedido"].count().to_frame()
# Out:
#                                numero_pedido
# cliente        estado_destino
# AMERICANAS     BH                        205
#                RJ                        200
#                SP                        186
# CASA E VIDEO   BH                        130
#                RJ                        132
#                SP                        123
# CASAS BAHIA    BH                        373
#                RJ                        314
#                SP                        329
# MAGAZINE LUIZA BH                        278
#                RJ                        251
#                SP                        280
# RICARDO ELETRO BH                        101
#                RJ                        106
#                SP                        117
# WALMART        BH                        409
#                RJ                        371
#                SP                        377

# %%
# Qual é o total de pedidos por motorista e por status?

dados.groupby(["motorista", "status"])["numero_pedido"].count().to_frame()
# Out:
#                           numero_pedido
# motorista       status
# FELIPE SILVA    Atrasado            469
#                 No Prazo            195
# JOÃO GOMES      Atrasado            494
#                 No Prazo            191
# LUIZ PARDAL     Atrasado            570
#                 No Prazo            180
# MARCOS LEROY    Atrasado            567
#                 No Prazo            186
# TÚLIO SILVEIRA  Atrasado            501
#                 No Prazo            197
# VALDIR ESPINOSA Atrasado            534
#                 No Prazo            198

# %% [markdown]
# ##### Visualização dos dados com PANDAS.

# %%
dados.head()
# Out:
#   numero_pedido         cliente        motorista dt_emissao_pedido  \
# 0            A3         WALMART     FELIPE SILVA        2019-01-27
# 1            A4  MAGAZINE LUIZA   TÚLIO SILVEIRA        2019-01-28
# 2            A7  MAGAZINE LUIZA  VALDIR ESPINOSA        2019-02-04
# 3           A12  MAGAZINE LUIZA     MARCOS LEROY        2019-02-18
# 4           A15         WALMART      LUIZ PARDAL        2019-02-21
#
#   estado_destino  valor_pedido dt_entrega motivo_devolucao    status
# 0             SP         139.5 2019-02-03       S/ Devolu.  No Prazo
# 1             RJ         134.4 2019-02-12       S/ Devolu.  Atrasado
# 2             SP          79.5 2019-02-14   Produto Errado  No Prazo
# 3             SP         326.0 2019-02-25   Produto Errado  No Prazo
# 4             RJ         597.6 2019-03-07       S/ Devolu.  Atrasado

# %%
dados["cliente"].value_counts()
# Out:
# cliente
# WALMART           1157
# CASAS BAHIA       1016
# MAGAZINE LUIZA     809
# AMERICANAS         591
# CASA E VIDEO       385
# RICARDO ELETRO     324
# Name: count, dtype: int64

# %%
# Criando um gráfico dos dados acima com o comando plot(), porém que seja um gráfico de barras

dados["cliente"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='cliente'>

# %%
# Pedidos por motorista

dados["motorista"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='motorista'>

# %%
# Status dos pedidos

dados["status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='status'>
